# %%
print ("Hello World!")
# Out:
# Hello World!

# %%
x = 1

# %%
y = 31

# %%
z = x * y

# %%
print(z)
# Out:
# 31

# %%
tempaverage = (temperature[0] + temperature[1] + temperature[2] + temperature[3] + temperature[4] + temperature[5]) / 6
print(tempaverage)
# Out:
# 69.16666666666667

# %%
import statistics

# %%
tempmean = statistics.mean(temperature)

# %%
print("mean = ", tempmean)
# Out:
# mean =  69.16666666666667

# %%
tempmedian = statistics.median(temperature)
print("median = ", tempmedian)
# Out:
# median =  65.0

# %%
grades = [70, 80, 80, 90, 100]
grademode = statistics.mode(grades)
print("mode = ", grademode)
# Out:
# mode =  80

# %%
grades = [70, 70, 80, 80, 90, 100]
grademode = statistics.mode(grades)
print("mode = ", grademode)
# Out:
# mode =  70

# %%
from matplotlib import pyplot
temperature = [40, 50, 60, 70, 80, 90, 100]
customer = [45, 70, 90, 180, 250, 300, 60]
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
pyplot.plot(temperature, customer)
pyplot.title("temp vs customer")
pyplot.xlabel("temperature")
pyplot.ylabel("customer")
pyplot.show()

# %%
x = 2
y = 5
x == y
# Out:
# False

# %%
x < y
# Out:
# True

# %%
x += y
print(x)
# Out:
# 7

# %%
x = ["Vi", "Caitlyn", "Jinx"]
y = "Echo"
y in x
# Out:
# False

# %%
x = 7
print(x > 2 and x < 8)
# Out:
# True

# %%
not(x > 2 or x < 8)
# Out:
# False

# %%
# if then

temp = 80
if temp <= 85:
    print("Nice weather")
# Out:
# Nice weather

# %%
# if then

if temp < 90 and temp > 50:
    print("Not bad")
# Out:
# Not bad

# %%
# if else 

temp = 100
if temp <= 85:
    print("nice weather")
else: 
    print("too hot")
# Out:
# too hot

# %%
# else if 

temp = 100
if temp <= 85:
    print("nice weather")
elif temp > 115:
    print("too hot")

# %%
# if else if else

temp = 100
if temp <= 85:
    print("nice weather")
elif temp > 115:
    print("zzzzz")
else:
    print("too hot")
# Out:
# too hot

# %%
# if if else 

temp = 78
rain = "yes"
if temp <= 85:
    print("nice weather")
    if rain == "yes":
        print("but it's raining")
    else:
        print("and sunny!")
# Out:
# nice weather
# but it's raining

# %%
# pass

temp = 78
rain = "yes"
if temp <= 85:
    pass

# %%
# count values in list

genre = ["Action", "Adventure", "Animation", "Biography", "Comedy", "Crime",
"Drama", "Family", "Fantasy", "History", "Horror", "Music", "Musical", "Mystery",
"Romance", "Sci‐Fi", "Sport", "Thriller", "War", "Western"]

count = 0
for value in genre:
    count += 1

print("There are ", count, " genres of movies in the list")
# Out:
# There are  20  genres of movies in the list

# %%
# print value in list 

for value in genre:
    print(value)
# Out:
# Action
# Adventure
# Animation
# Biography
# Comedy
# Crime
# Drama
# Family
# Fantasy
# History
# Horror
# Music
# Musical
# Mystery
# Romance
# Sci‐Fi
# Sport
# Thriller
# War
# Western

# %%
# break in for loop

for value in genre:
    print(value)
    if value == "Comedy":
        break
# Out:
# Action
# Adventure
# Animation
# Biography
# Comedy

# %%
# print value in for loop

for value in 'data science':
    print(value)
# Out:
# d
# a
# t
# a
#
# s
# c
# i
# e
# n
# c
# e

# %%
# for loop

base = input("Enter an integer base number")
exponent = input("Enter a positive exponent number")
result = 1

base = int(base)
exponent = int(exponent)

for i in range (0, exponent):
    result = result * base
    print(result)
# Out:
# Enter an integer base number 9
# Enter a positive exponent number 3
# 9
# 81
# 729

# %%
# while loop

base = input("Enter an integer base number")
exponent = input("Enter a positive exponent number")
result = 1

base = int(base)
exponent = int(exponent)

i = 0
while i < exponent: 
    result *= base
    i += 1

print(result)
# Out:
# Enter an integer base number 2
# Enter a positive exponent number 2
# 2
# 4
